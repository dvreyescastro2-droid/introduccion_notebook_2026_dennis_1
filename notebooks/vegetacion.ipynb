# %% [markdown]
# # Diagnóstico básico de cobertura vegetal
#
# **Nombre:** Lizeth León
# **Rol:** Cobertura vegetal
# **Punto de monitoreo:** Parque Simón Bolívar

# %%
print("Diagnóstico básico de cobertura vegetal")

punto = input("Ingrese el punto de monitoreo: ")

area_total = float(input("Área total (m2): "))
area_vegetacion = float(input("Área con vegetación (m2): "))
arboles = int(input("Número de árboles: "))

area_sin = area_total - area_vegetacion
porcentaje = (area_vegetacion / area_total) * 100
densidad = arboles / area_total

print("Cobertura vegetal:", porcentaje, "%")
# Out:
# Diagnóstico básico de cobertura vegetal
# Cobertura vegetal: 61.94690265486725 %
