# %% [markdown]
# ## Mejora en desarrollo
#
# **Nombre:** Lizeth Leon
# Estoy trabajando en una mejora sin tocar producción.

# %%
print("Estoy trabajando en una mejora (feature).")
print("Mi nombre es: Lizeth Leon")
# Out:
# Estoy trabajando en una mejora (feature).
# Mi nombre es: Lizeth Leon

# %%
print("Volví a mi mejora después del hotfix.")
# Out:
# Volví a mi mejora después del hotfix.

# %% [markdown]
# ## Reflexión
#
# 1. Si trabajaba directamente en `main`, podía afectar la versión principal del proyecto.
# 2. El hotfix se hizo en otra rama para corregir un problema urgente sin mezclarlo con la mejora.
# 3. GitHub sirve para trabajar en equipo, controlar versiones y organizar cambios.
