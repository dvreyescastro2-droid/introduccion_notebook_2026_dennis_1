# %% [markdown]
# # Dennis Vanessa Reyes Castro
# **Programa académico:** Ingeniería Ambiental
#
# ## Reflexión
# La programación puede apoyar la Ingeniería Ambiental permitiendo analizar
# grandes volúmenes de datos ambientales de forma eficiente. Con código podemos
# modelar y operar fenómenos como la contaminación del agua o el cambio climático.
# Además, automatizar procesos de monitoreo reduce errores y mejora
# la toma de decisiones en proyectos de conservación ambiental.

# %%
print("El acceso al agua potable es un derecho fundamental. La programación nos ayuda a monitorear y proteger este recurso vital.")
